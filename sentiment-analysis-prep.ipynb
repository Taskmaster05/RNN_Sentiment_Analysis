# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
from nltk.tokenize import TweetTokenizer

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/kaggle/input/hate-speech-and-offensive-language-dataset/labeled_data.csv")[["class", "tweet"]]
df.head()
# Out:
#    class                                              tweet
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   24783 non-null  int64
#  1   tweet   24783 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 387.4+ KB

# %%
sw = set(stopwords.words('english'))
tokenizer = TweetTokenizer()

def prep_tweet(tweet):
    tweet = tweet.lower()
    tweet = tokenizer.tokenize(tweet)
    tweet = [w for w in tweet if w not in sw]
    
    return tweet

# %%
df["tweet"] = df["tweet"].astype("str")

for i in range(len(df)):
    df.tweet.iloc[i] = prep_tweet(df.tweet.iloc[i])

# %%
df["tweet"]
# Out:
# 0        [!, !, !, rt, @mayasolovely, :, woman, complai...
# 1        [!, !, !, rt, @mleew17, :, boy, dats, cold, .....
# 2        [!, !, !, rt, @urkindofbrand, dawg, !, !, !, r...
# 3        [!, !, !, rt, @c_g_anderson, :, @viva_based, l...
# 4        [!, !, !, rt, @shenikaroberts, :, shit, hear, ...
#                                ...
# 24778    [you's, muthaf, *, *, *, lie, “, @lifeasking, ...
# 24779    [gone, broke, wrong, heart, baby, ,, drove, re...
# 24780    [young, buck, wanna, eat, !, !, .., dat, niggu...
# 24781             [youu, got, wild, bitches, tellin, lies]
# 24782    [~, ~, ruffled, |, ntac, eileen, dahlia, -, be...
# Name: tweet, Length: 24783, dtype: object

# %%
df.to_csv("/kaggle/working/train_prepped.csv", index = False)
